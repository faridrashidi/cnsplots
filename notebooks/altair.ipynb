# %%
import cnsplots as cns
cns.setup_altair()
df = sns.load_dataset('iris')

# %%
df = pd.DataFrame({'Choice':["My own research","Someone else's", "Both", "Never had problems"], 'Count':[1,3,4,0]})
bars = alt.Chart(df).mark_bar().encode(x='Count', y=alt.X('Choice', sort=None))
text = bars.mark_text(align='left', baseline='middle', dx=3, size=8).encode(text='Count:Q')
(bars + text).properties(width=200, height=80)
alts.save(bars + text, '/Users/rashidimehrabf2/Desktop/salam.pdf')

# %%
p = alt.Chart(df).mark_boxplot().encode(x='species', y='sepal_length')#, color=alt.Color('species', legend=None))
# outliers={'size':8,'filled':True}
p = p.properties(width=150, height=180)
p
# print(p.to_json())
# alts.save(p, '/Users/farid/Desktop/salam.pdf')
# Out:
# alt.Chart(...)

# %%
# alt.Chart(df).transform_density('sepal_length',as_=['sepal_length','density']).mark_area(color='black').encode(x='sepal_length:Q',y='density:Q')
# Out:
# alt.Chart(...)

# %%
p = alt.Chart(df).mark_point().encode(x='sepal_length', y='sepal_width')
p
# save(g, '/Users/farid/Desktop/salam.pdf')
# Out:
# alt.Chart(...)

# %%
df['petal_width_range'] = df['petal_width'] > 1
p = alt.Chart(df).mark_rect().encode(x='species', y='petal_width_range', color='petal_length')
p.properties(width=200, height=200)
# Out:
# alt.Chart(...)

# %%
alt.Chart(df).mark_line().encode(x='petal_length', y='sepal_length')
# Out:
# alt.Chart(...)

# %%
## UpSet plot: https://github.com/hms-dbmi/upset-altair-notebook/blob/master/index.ipynb
