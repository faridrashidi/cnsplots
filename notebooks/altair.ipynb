# %%
import cnsplots as cns
cns.setup_altair()
df = sns.load_dataset('iris')

# %%
df2 = pd.DataFrame({'Choice':["My own research","Someone else's", "Both", "Never had problems"], 'Count':[1,3,4,0]})
bars = alt.Chart(df2).mark_bar().encode(x='Count', y=alt.X('Choice', sort=None))
text = bars.mark_text(align='left', baseline='middle', dx=3, size=8).encode(text='Count:Q')
(bars + text).properties(height=80, width=200)
# alts.save(bars + text, '../../../Desktop/salam.pdf')
# Out:
# alt.LayerChart(...)

# %%
p = alt.Chart(df).mark_boxplot().encode(x='species', y='sepal_length')#, color=alt.Color('species', legend=None))
# outliers={'size':8,'filled':True}
p = p.properties(height=180, width=100)
p
# print(p.to_json())
# alts.save(p, '../../../salam.pdf')
# Out:
# alt.Chart(...)

# %%
alt.Chart(df).transform_density(
    "sepal_length", as_=["sepal_length", "density"]
).mark_area().encode(x="sepal_length:Q", y="density:Q")
# Out:
# alt.Chart(...)

# %%
alt.Chart(df).mark_point().encode(x='sepal_length', y='sepal_width')
# Out:
# alt.Chart(...)

# %%
df['petal_width_range'] = df['petal_width'] > 1
p = alt.Chart(df).mark_rect().encode(x='species', y='petal_width_range', color='petal_length')
p.properties(height=200, width=200)
# Out:
# alt.Chart(...)

# %%
alt.Chart(df).mark_line().encode(x='petal_length', y='sepal_length')
# Out:
# alt.Chart(...)

# %%
## UpSet plot: https://github.com/hms-dbmi/upset-altair-notebook/blob/master/index.ipynb
