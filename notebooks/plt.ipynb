# %%
import cnsplots as cns
cns.setup_matplotlib()

# %%
plt.figure(figsize=(120 / 72, 120 / 72), dpi=72)
df = sns.load_dataset("iris")
sns.scatterplot(data=df, x="sepal_length", y="sepal_width", s=7, hue='species')
plt.savefig('/Users/farid/Desktop/salam.pdf')

# %%
plt.figure(figsize=(120 / 72, 120 / 72), dpi=72)
sns.histplot(data=df, x="sepal_width")
# Out:
# <AxesSubplot: xlabel='sepal_width', ylabel='Count'>

# %%
# x = np.linspace(0.75, 1.25, 201)
# plt.plot(x, x)
# plt.xlabel('salam')
# plt.ylabel('salam')
# plt.savefig('/Users/farid/Desktop/salam.pdf')

# %%
# adata = sc.datasets.krumsiek11()
# sc.pl.heatmap(adata, adata.var_names, 'cell_type', use_raw=False, show=False, dendrogram=True)

# %%
adata = sc.datasets.pbmc68k_reduced()
sc.pl.umap(adata, color="HES4")
